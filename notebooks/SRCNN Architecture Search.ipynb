# %% [markdown]
# # SRCNN - architecture search
# This notebook implements the super-resolution convolutional neural network, SRCNN, as described by [Dong *et al.*](https://link.springer.com/chapter/10.1007/978-3-319-10593-2_13).
#
# The notebook will cover the 3 scaling factors described in the paper: $2\times$, $3\times$, $4\times$. Results for each can be acquired by changing the scaling factor and re-running the notebook.
#
# ## Summary
# Results from this notebook are summarized. Using $32 \times 32$ training patches ($33 \times 33$ for scaling factor 3), image patch stride of 14, training batch size of 64 and 500 epochs, training took roughly 5 minutes on a GTX 1080 Ti.
#
# | Scaling factor | Image Set | Bicubic - PSNR (mean) | SRCNN - PSNR (mean) | PSNR Mean Improvement | Bicubic - SSIM (mean) | SRCNN - SSIM (mean) | SSIM Mean Improvement |
# | :------------- | :-------: | :-------------------: | :-----------------: | :-------------------: | :-------------------: | :-----------------: | :-------------------: |
# | $2\times$ | Set5 |$25.81$ dB | $26.88$ dB | $+1.06$ dB | $0.76$ | $0.80$ | $+0.04$ |
# | $2\times$ | Set14 | $23.54$ dB | $24.38$ dB | $+0.84$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $3\times$ | Set5 |$23.60$ dB | $24.06$ dB | $+0.45$ dB | $0.67$ | $0.69$ | $+0.02$ |
# | $3\times$ | Set14 | $21.84$ dB | $22.24$ dB | $+0.41$ dB | $0.56$ | $0.58$ | $+0.02$ |
# | $4\times$ | Set5 |$21.67$ dB | $22.52$ dB | $+0.85$ dB | $0.59$ | $0.62$ | $+0.03$ |
# | $4\times$ | Set14 | $20.29$ dB | $20.86$ dB | $+0.57$ dB | $0.50$ | $0.52$ | $+0.02$ |

# %%
# Imports.
import numpy as np
from PIL import Image

import site
site.addsitedir('../')
from srcnn_tf2.data.preprocessing import create_xy_patches, import_from_file, scale_batch, center_crop
from srcnn_tf2.data.plotting import n_compare
from srcnn_tf2.model.srcnn_model import SRCNN

# Data locations.
training_folder = '../../../sr_data/T91'
set5_eval_folder = '../../../sr_data/Set5'
set14_eval_folder = '../../../sr_data/Set14'

# %% [markdown]
# ---
# ## Import and preprocess training data
# High-resolution target images, $I_y$, are 32 x 32 pixel sub-images extracted from the original T91 image set. This is done by passing a 32 x 32 pixel window over the originals at a stride of 14 pixels. Target images are then given a Gaussian blur and downscaled by the scaling factor to produce the low-resolution input images, $I_x$. Pre-upscaling for the model is performed as part of the model class.
#
# **Note** that applying the blur after the downscale produces better numerical and visual results on the images that are downscaled for validation (e.g. Set5 and Set14). However, applying the blur before downscaling, as in the paper, while returning seemingly worse numerical and visual results on the validation set, produces far more realistic images when tested on CIFAR-10.
#
# To avoid edge effects of convlution, padding in the model is set to `'valid'`, and $I_y$ images are center cropped to remove the edge, forcing the loss function to compare only the central $20 x 20$ section of the image.
#
# Note that the number of training images found here under 32 x 32 image size and 14 pixel stride is $22,623$, which is slightly less than the $24,800$ images obtained in the original paper. We have used a stride of 14 pixels in both $x-$ and $y-$directions, as we believe the original paper has, but have not identified another source of discrepancy. Minimum accepted stride is $1$, so we do not discard any pixels at the end of an image if 14 does not divide into the image size evenly.

# %%
# Data options.
# Note: 'scaling_factor' should evenly divide into 'y_image_size'.
y_image_size = (32, 32)  # Target image size, patches extracted from T91 inputs.
scaling_factor = 2
patch_stride = 14
blur_kernel = -1

# Data extraction.
xdata, ydata = create_xy_patches(training_folder,
                                 scaling_factor,
                                 patch_size=y_image_size,
                                 patch_stride=patch_stride,
                                 blur_kernel=blur_kernel,
                                 rotations=[0], swap_channels=False)
print(f"Target data size (number of images x image shape x channels): {ydata.shape}")
print(f"Training data input size (number of images x image shape x channels): {xdata.shape}")
# Out:
# Target data size (number of images x image shape x channels): (22623, 32, 32, 3)
# Training data input size (number of images x image shape x channels): (22623, 16, 16, 3)

# %% [markdown]
# ## Define and train models
# ### Define model architectures
# Models are defined in a loop, using a range of parameters. Here we do a grid search across the filter sizes, as well as the number of filters and non-linear layers. Constraints on architecture are based on those found in the paper, where $n_2 \leq n_1$ and $f1 \leq f_3$.

# %%
# Model architectures are defined in a list of tuples, containing:
#     (f1, f3, n1, n2, nlin_layers)

f1_range = [9, 13, 17]
f3_range = [5, 7, 11]
n1_range = [64, 128, 256]
n2_range = [32, 64, 128]
nlin_range = [1, 4, 8]

arch_list = []

for f1_i in f1_range:
    for f3_i in f3_range:
        for n1_i in n1_range:
            for n2_i in n2_range:
                for nlin_i in nlin_range:
                    if (f3_i <= f1_i) & (n2_i <= n1_i):
                        arch_list.append((f1_i, f3_i, n1_i, n2_i, nlin_i))

# %% [markdown]
# ### Train model architectures
# Specify number of epochs and batch size. Use a small split for running validation, and plot the loss and validation loss.

# %%
testing_images_14 = import_from_file(set14_eval_folder)
batch_size = 32  # use slightly smaller size in case of large models using all VRAM
epochs = 10
result_strings = []

for arch in arch_list:
    print(f"\n====================================================\nModel Architecture: {arch}")
    srcnn_m = SRCNN(
        num_channels=3,
        f1=arch[0],
        f3=arch[1],
        n1=arch[2],
        n2=arch[3],
        nlin_layers=arch[4],
        activation='relu', optimizer='adam', loss='mse', metrics=['accuracy'], padding='valid', batch_norm=False)
    srcnn_m.fit(xdata=xdata, ydata=ydata, epochs=epochs, batch_size=batch_size, validation_split=0.1, verbose=0)
    srcnn_m.plot_training(figsize=(16, 8), plot_vars=['loss', 'val_loss'])
    
    psnr_14, psnr_bicubic_14 = srcnn_m.benchmark(testing_images_14, metric='psnr', return_metrics=True)
    ssim_14, ssim_bicubic_14 = srcnn_m.benchmark(testing_images_14, metric='ssim', return_metrics=True)
    
    result_strings.append(
        f"| ${scaling_factor}\\times$ | Set14 | {' / '.join([str(a) for a in arch])} |"+
        f" ${np.mean(psnr_bicubic_14):.2f}$ dB | ${np.mean(psnr_14):.2f}$ dB |"+
        f" $+{np.mean(psnr_14) - np.mean(psnr_bicubic_14):.2f}$ dB |"+
        f" ${np.mean(ssim_bicubic_14):.2f}$ | ${np.mean(ssim_14):.2f}$ | $+{np.mean(ssim_14) - np.mean(ssim_bicubic_14):.2f}$ |"
    )
# Out:
# Model Architecture: (9, 5, 64, 32, 1)
# 10 epochs completed in 0.0 minutes 10.31 seconds, approx. 1.03 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.4
# 		5.2. PSNR: 23.4
# 		5.3. PSNR: 28.2
# 		5.4. PSNR: 20.5
# 		5.5. PSNR: 23.6
# 		5.6. PSNR: 24.8
# 		5.7. PSNR: 28.4
# 		5.8. PSNR: 23.6
# 		5.9. PSNR: 29.0
# 		5.10. PSNR: 21.9
# 		5.11. PSNR: 24.0
# 		5.12. PSNR: 24.4
# 		5.13. PSNR: 28.0
# 		5.14. PSNR: 20.6
# 	Average PSNR: 24.351
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.690
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 64, 32, 4)
# 10 epochs completed in 0.0 minutes 14.22 seconds, approx. 1.42 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.4
# 		5.3. PSNR: 27.4
# 		5.4. PSNR: 20.8
# 		5.5. PSNR: 23.8
# 		5.6. PSNR: 24.9
# 		5.7. PSNR: 28.5
# 		5.8. PSNR: 23.7
# 		5.9. PSNR: 28.9
# 		5.10. PSNR: 21.7
# 		5.11. PSNR: 23.9
# 		5.12. PSNR: 24.3
# 		5.13. PSNR: 27.9
# 		5.14. PSNR: 20.6
# 	Average PSNR: 24.273
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.690
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 64, 32, 8)
# 10 epochs completed in 0.0 minutes 19.71 seconds, approx. 1.97 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.4
# 		5.3. PSNR: 27.3
# 		5.4. PSNR: 20.6
# 		5.5. PSNR: 23.9
# 		5.6. PSNR: 24.8
# 		5.7. PSNR: 28.0
# 		5.8. PSNR: 23.5
# 		5.9. PSNR: 28.9
# 		5.10. PSNR: 22.1
# 		5.11. PSNR: 23.7
# 		5.12. PSNR: 24.4
# 		5.13. PSNR: 27.5
# 		5.14. PSNR: 20.5
# 	Average PSNR: 24.209
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.687
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 64, 32, 16)
# 10 epochs completed in 0.0 minutes 30.36 seconds, approx. 3.04 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.4
# 		5.3. PSNR: 26.9
# 		5.4. PSNR: 20.9
# 		5.5. PSNR: 23.6
# 		5.6. PSNR: 24.8
# 		5.7. PSNR: 28.2
# 		5.8. PSNR: 23.7
# 		5.9. PSNR: 28.7
# 		5.10. PSNR: 21.8
# 		5.11. PSNR: 23.7
# 		5.12. PSNR: 23.9
# 		5.13. PSNR: 27.7
# 		5.14. PSNR: 20.6
# 	Average PSNR: 24.163
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.689
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 64, 64, 1)
# 10 epochs completed in 0.0 minutes 11.66 seconds, approx. 1.17 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.2
# 		5.2. PSNR: 23.1
# 		5.3. PSNR: 26.8
# 		5.4. PSNR: 19.4
# 		5.5. PSNR: 23.7
# 		5.6. PSNR: 24.3
# 		5.7. PSNR: 25.5
# 		5.8. PSNR: 23.0
# 		5.9. PSNR: 28.1
# 		5.10. PSNR: 23.1
# 		5.11. PSNR: 23.6
# 		5.12. PSNR: 25.2
# 		5.13. PSNR: 26.4
# 		5.14. PSNR: 20.0
# 	Average PSNR: 23.739
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.685
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 64, 64, 4)
# 10 epochs completed in 0.0 minutes 19.82 seconds, approx. 1.98 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.3
# 		5.3. PSNR: 27.3
# 		5.4. PSNR: 20.1
# 		5.5. PSNR: 23.7
# 		5.6. PSNR: 24.7
# 		5.7. PSNR: 27.5
# 		5.8. PSNR: 23.4
# 		5.9. PSNR: 28.7
# 		5.10. PSNR: 22.3
# 		5.11. PSNR: 23.8
# 		5.12. PSNR: 24.2
# 		5.13. PSNR: 27.7
# 		5.14. PSNR: 20.4
# 	Average PSNR: 24.095
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.687
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 64, 64, 8)
# 10 epochs completed in 0.0 minutes 30.18 seconds, approx. 3.02 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.1
# 		5.2. PSNR: 23.3
# 		5.3. PSNR: 26.8
# 		5.4. PSNR: 20.9
# 		5.5. PSNR: 23.6
# 		5.6. PSNR: 24.8
# 		5.7. PSNR: 28.3
# 		5.8. PSNR: 23.6
# 		5.9. PSNR: 28.8
# 		5.10. PSNR: 21.7
# 		5.11. PSNR: 23.8
# 		5.12. PSNR: 23.6
# 		5.13. PSNR: 27.7
# 		5.14. PSNR: 20.5
# 	Average PSNR: 24.113
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.687
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 64, 64, 16)
# 10 epochs completed in 0.0 minutes 51.69 seconds, approx. 5.17 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.4
# 		5.3. PSNR: 27.2
# 		5.4. PSNR: 20.8
# 		5.5. PSNR: 23.3
# 		5.6. PSNR: 24.7
# 		5.7. PSNR: 28.5
# 		5.8. PSNR: 23.6
# 		5.9. PSNR: 28.7
# 		5.10. PSNR: 21.5
# 		5.11. PSNR: 23.9
# 		5.12. PSNR: 23.8
# 		5.13. PSNR: 27.5
# 		5.14. PSNR: 20.5
# 	Average PSNR: 24.122
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.688
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 128, 32, 1)
# 10 epochs completed in 0.0 minutes 11.47 seconds, approx. 1.15 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.0
# 		5.3. PSNR: 27.4
# 		5.4. PSNR: 19.9
# 		5.5. PSNR: 23.8
# 		5.6. PSNR: 24.5
# 		5.7. PSNR: 26.9
# 		5.8. PSNR: 23.3
# 		5.9. PSNR: 28.6
# 		5.10. PSNR: 22.6
# 		5.11. PSNR: 23.8
# 		5.12. PSNR: 25.0
# 		5.13. PSNR: 27.3
# 		5.14. PSNR: 20.3
# 	Average PSNR: 24.039
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.685
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 128, 32, 4)
# 10 epochs completed in 0.0 minutes 15.64 seconds, approx. 1.56 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.4
# 		5.3. PSNR: 27.7
# 		5.4. PSNR: 20.6
# 		5.5. PSNR: 23.5
# 		5.6. PSNR: 24.8
# 		5.7. PSNR: 28.2
# 		5.8. PSNR: 23.5
# 		5.9. PSNR: 29.0
# 		5.10. PSNR: 21.8
# 		5.11. PSNR: 23.9
# 		5.12. PSNR: 24.2
# 		5.13. PSNR: 27.9
# 		5.14. PSNR: 20.5
# 	Average PSNR: 24.249
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.687
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 128, 32, 8)
# 10 epochs completed in 0.0 minutes 21.02 seconds, approx. 2.10 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.2
# 		5.2. PSNR: 23.2
# 		5.3. PSNR: 26.3
# 		5.4. PSNR: 20.2
# 		5.5. PSNR: 23.6
# 		5.6. PSNR: 24.5
# 		5.7. PSNR: 26.3
# 		5.8. PSNR: 23.4
# 		5.9. PSNR: 28.4
# 		5.10. PSNR: 22.3
# 		5.11. PSNR: 23.4
# 		5.12. PSNR: 23.7
# 		5.13. PSNR: 27.2
# 		5.14. PSNR: 20.2
# 	Average PSNR: 23.779
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.688
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 128, 32, 16)
# 10 epochs completed in 0.0 minutes 31.93 seconds, approx. 3.19 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.3
# 		5.3. PSNR: 27.6
# 		5.4. PSNR: 20.7
# 		5.5. PSNR: 23.6
# 		5.6. PSNR: 24.7
# 		5.7. PSNR: 28.4
# 		5.8. PSNR: 23.6
# 		5.9. PSNR: 28.8
# 		5.10. PSNR: 21.8
# 		5.11. PSNR: 23.9
# 		5.12. PSNR: 24.0
# 		5.13. PSNR: 28.0
# 		5.14. PSNR: 20.6
# 	Average PSNR: 24.226
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.687
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 128, 64, 1)
# 10 epochs completed in 0.0 minutes 13.16 seconds, approx. 1.32 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.4
# 		5.2. PSNR: 23.4
# 		5.3. PSNR: 28.0
# 		5.4. PSNR: 20.4
# 		5.5. PSNR: 23.7
# 		5.6. PSNR: 24.7
# 		5.7. PSNR: 27.8
# 		5.8. PSNR: 23.5
# 		5.9. PSNR: 28.9
# 		5.10. PSNR: 22.3
# 		5.11. PSNR: 23.9
# 		5.12. PSNR: 24.2
# 		5.13. PSNR: 27.9
# 		5.14. PSNR: 20.5
# 	Average PSNR: 24.259
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.690
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 128, 64, 4)
# 10 epochs completed in 0.0 minutes 21.33 seconds, approx. 2.13 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.3
# 		5.3. PSNR: 27.9
# 		5.4. PSNR: 20.2
# 		5.5. PSNR: 23.5
# 		5.6. PSNR: 24.7
# 		5.7. PSNR: 28.2
# 		5.8. PSNR: 23.5
# 		5.9. PSNR: 28.8
# 		5.10. PSNR: 21.9
# 		5.11. PSNR: 23.9
# 		5.12. PSNR: 24.5
# 		5.13. PSNR: 27.9
# 		5.14. PSNR: 20.5
# 	Average PSNR: 24.229
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.685
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 128, 64, 8)
# 10 epochs completed in 0.0 minutes 32.26 seconds, approx. 3.23 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.2
# 		5.2. PSNR: 22.9
# 		5.3. PSNR: 26.0
# 		5.4. PSNR: 20.3
# 		5.5. PSNR: 23.4
# 		5.6. PSNR: 24.5
# 		5.7. PSNR: 27.5
# 		5.8. PSNR: 23.4
# 		5.9. PSNR: 28.3
# 		5.10. PSNR: 21.8
# 		5.11. PSNR: 23.7
# 		5.12. PSNR: 23.8
# 		5.13. PSNR: 27.2
# 		5.14. PSNR: 20.3
# 	Average PSNR: 23.813
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.679
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 128, 64, 16)
# 10 epochs completed in 0.0 minutes 52.13 seconds, approx. 5.21 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.4
# 		5.3. PSNR: 26.4
# 		5.4. PSNR: 20.6
# 		5.5. PSNR: 23.8
# 		5.6. PSNR: 24.7
# 		5.7. PSNR: 27.9
# 		5.8. PSNR: 23.5
# 		5.9. PSNR: 28.7
# 		5.10. PSNR: 22.1
# 		5.11. PSNR: 23.5
# 		5.12. PSNR: 24.6
# 		5.13. PSNR: 27.7
# 		5.14. PSNR: 20.5
# 	Average PSNR: 24.122
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.687
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 128, 128, 1)
# 10 epochs completed in 0.0 minutes 16.44 seconds, approx. 1.64 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.4
# 		5.2. PSNR: 23.4
# 		5.3. PSNR: 28.2
# 		5.4. PSNR: 20.7
# 		5.5. PSNR: 23.6
# 		5.6. PSNR: 24.8
# 		5.7. PSNR: 28.3
# 		5.8. PSNR: 23.6
# 		5.9. PSNR: 28.9
# 		5.10. PSNR: 21.9
# 		5.11. PSNR: 24.0
# 		5.12. PSNR: 24.4
# 		5.13. PSNR: 28.0
# 		5.14. PSNR: 20.6
# 	Average PSNR: 24.347
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.691
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 128, 128, 4)
# 10 epochs completed in 0.0 minutes 29.88 seconds, approx. 2.99 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.5
# 		5.3. PSNR: 27.8
# 		5.4. PSNR: 20.8
# 		5.5. PSNR: 23.8
# 		5.6. PSNR: 24.8
# 		5.7. PSNR: 28.5
# 		5.8. PSNR: 23.6
# 		5.9. PSNR: 29.0
# 		5.10. PSNR: 21.9
# 		5.11. PSNR: 24.0
# 		5.12. PSNR: 24.2
# 		5.13. PSNR: 27.9
# 		5.14. PSNR: 20.6
# 	Average PSNR: 24.342
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.691
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 128, 128, 8)
# 10 epochs completed in 0.0 minutes 47.65 seconds, approx. 4.77 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.0
# 		5.2. PSNR: 22.2
# 		5.3. PSNR: 27.0
# 		5.4. PSNR: 18.2
# 		5.5. PSNR: 23.5
# 		5.6. PSNR: 23.9
# 		5.7. PSNR: 25.4
# 		5.8. PSNR: 22.8
# 		5.9. PSNR: 27.5
# 		5.10. PSNR: 23.3
# 		5.11. PSNR: 22.4
# 		5.12. PSNR: 25.9
# 		5.13. PSNR: 25.6
# 		5.14. PSNR: 19.4
# 	Average PSNR: 23.375
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.6
# 		5.10. SSIM: 0.6
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.656
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 128, 128, 16)
# 10 epochs completed in 1.0 minutes 20.62 seconds, approx. 8.06 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.2
# 		5.2. PSNR: 23.3
# 		5.3. PSNR: 26.6
# 		5.4. PSNR: 20.7
# 		5.5. PSNR: 23.6
# 		5.6. PSNR: 24.6
# 		5.7. PSNR: 28.2
# 		5.8. PSNR: 23.6
# 		5.9. PSNR: 28.8
# 		5.10. PSNR: 21.4
# 		5.11. PSNR: 23.7
# 		5.12. PSNR: 23.9
# 		5.13. PSNR: 27.6
# 		5.14. PSNR: 20.4
# 	Average PSNR: 24.037
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.686
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 256, 32, 1)
# 10 epochs completed in 0.0 minutes 15.98 seconds, approx. 1.60 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.4
# 		5.2. PSNR: 23.3
# 		5.3. PSNR: 28.1
# 		5.4. PSNR: 20.2
# 		5.5. PSNR: 23.6
# 		5.6. PSNR: 24.8
# 		5.7. PSNR: 27.7
# 		5.8. PSNR: 23.5
# 		5.9. PSNR: 28.7
# 		5.10. PSNR: 22.4
# 		5.11. PSNR: 24.1
# 		5.12. PSNR: 24.8
# 		5.13. PSNR: 28.0
# 		5.14. PSNR: 20.5
# 	Average PSNR: 24.293
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.689
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 256, 32, 4)
# 10 epochs completed in 0.0 minutes 19.85 seconds, approx. 1.98 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.2
# 		5.2. PSNR: 22.9
# 		5.3. PSNR: 27.3
# 		5.4. PSNR: 19.8
# 		5.5. PSNR: 23.5
# 		5.6. PSNR: 24.4
# 		5.7. PSNR: 26.3
# 		5.8. PSNR: 23.1
# 		5.9. PSNR: 28.2
# 		5.10. PSNR: 22.2
# 		5.11. PSNR: 23.7
# 		5.12. PSNR: 24.5
# 		5.13. PSNR: 27.0
# 		5.14. PSNR: 20.2
# 	Average PSNR: 23.812
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.682
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 256, 32, 8)
# 10 epochs completed in 0.0 minutes 25.31 seconds, approx. 2.53 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.4
# 		5.3. PSNR: 27.4
# 		5.4. PSNR: 20.5
# 		5.5. PSNR: 23.6
# 		5.6. PSNR: 24.8
# 		5.7. PSNR: 28.0
# 		5.8. PSNR: 23.6
# 		5.9. PSNR: 28.8
# 		5.10. PSNR: 22.1
# 		5.11. PSNR: 23.8
# 		5.12. PSNR: 24.0
# 		5.13. PSNR: 27.9
# 		5.14. PSNR: 20.5
# 	Average PSNR: 24.199
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.688
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 256, 32, 16)
# 10 epochs completed in 0.0 minutes 35.78 seconds, approx. 3.58 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.3
# 		5.3. PSNR: 27.6
# 		5.4. PSNR: 20.6
# 		5.5. PSNR: 23.6
# 		5.6. PSNR: 24.7
# 		5.7. PSNR: 28.2
# 		5.8. PSNR: 23.6
# 		5.9. PSNR: 28.9
# 		5.10. PSNR: 21.7
# 		5.11. PSNR: 23.9
# 		5.12. PSNR: 24.1
# 		5.13. PSNR: 28.0
# 		5.14. PSNR: 20.5
# 	Average PSNR: 24.212
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.685
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 256, 64, 1)
# 10 epochs completed in 0.0 minutes 17.92 seconds, approx. 1.79 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.3
# 		5.3. PSNR: 27.9
# 		5.4. PSNR: 20.6
# 		5.5. PSNR: 23.7
# 		5.6. PSNR: 24.8
# 		5.7. PSNR: 28.4
# 		5.8. PSNR: 23.5
# 		5.9. PSNR: 29.0
# 		5.10. PSNR: 21.9
# 		5.11. PSNR: 24.0
# 		5.12. PSNR: 24.3
# 		5.13. PSNR: 27.9
# 		5.14. PSNR: 20.5
# 	Average PSNR: 24.297
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.689
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 256, 64, 4)
# 10 epochs completed in 0.0 minutes 25.86 seconds, approx. 2.59 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.2
# 		5.3. PSNR: 27.0
# 		5.4. PSNR: 20.2
# 		5.5. PSNR: 23.7
# 		5.6. PSNR: 24.7
# 		5.7. PSNR: 27.6
# 		5.8. PSNR: 23.4
# 		5.9. PSNR: 28.8
# 		5.10. PSNR: 22.1
# 		5.11. PSNR: 23.8
# 		5.12. PSNR: 24.5
# 		5.13. PSNR: 27.6
# 		5.14. PSNR: 20.4
# 	Average PSNR: 24.086
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.684
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 256, 64, 8)
# 10 epochs completed in 0.0 minutes 36.25 seconds, approx. 3.63 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.2
# 		5.2. PSNR: 23.5
# 		5.3. PSNR: 26.9
# 		5.4. PSNR: 20.6
# 		5.5. PSNR: 24.0
# 		5.6. PSNR: 24.9
# 		5.7. PSNR: 28.2
# 		5.8. PSNR: 23.7
# 		5.9. PSNR: 28.9
# 		5.10. PSNR: 21.9
# 		5.11. PSNR: 23.7
# 		5.12. PSNR: 24.3
# 		5.13. PSNR: 27.9
# 		5.14. PSNR: 20.5
# 	Average PSNR: 24.229
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.690
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 256, 64, 16)
# 10 epochs completed in 0.0 minutes 56.98 seconds, approx. 5.70 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.2
# 		5.2. PSNR: 23.3
# 		5.3. PSNR: 27.2
# 		5.4. PSNR: 20.9
# 		5.5. PSNR: 23.9
# 		5.6. PSNR: 24.7
# 		5.7. PSNR: 28.3
# 		5.8. PSNR: 23.6
# 		5.9. PSNR: 28.9
# 		5.10. PSNR: 21.8
# 		5.11. PSNR: 23.7
# 		5.12. PSNR: 24.2
# 		5.13. PSNR: 27.6
# 		5.14. PSNR: 20.3
# 	Average PSNR: 24.184
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.687
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 256, 128, 1)
# 10 epochs completed in 0.0 minutes 21.07 seconds, approx. 2.11 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.4
# 		5.2. PSNR: 23.5
# 		5.3. PSNR: 28.2
# 		5.4. PSNR: 20.6
# 		5.5. PSNR: 23.7
# 		5.6. PSNR: 24.8
# 		5.7. PSNR: 28.4
# 		5.8. PSNR: 23.6
# 		5.9. PSNR: 28.9
# 		5.10. PSNR: 21.9
# 		5.11. PSNR: 24.1
# 		5.12. PSNR: 24.8
# 		5.13. PSNR: 27.9
# 		5.14. PSNR: 20.6
# 	Average PSNR: 24.376
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.690
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 256, 128, 4)
# 10 epochs completed in 0.0 minutes 34.45 seconds, approx. 3.44 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.4
# 		5.3. PSNR: 27.8
# 		5.4. PSNR: 20.5
# 		5.5. PSNR: 23.3
# 		5.6. PSNR: 24.7
# 		5.7. PSNR: 27.8
# 		5.8. PSNR: 23.5
# 		5.9. PSNR: 28.8
# 		5.10. PSNR: 22.2
# 		5.11. PSNR: 24.0
# 		5.12. PSNR: 23.8
# 		5.13. PSNR: 27.9
# 		5.14. PSNR: 20.5
# 	Average PSNR: 24.174
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.687
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 256, 128, 8)
# 10 epochs completed in 0.0 minutes 51.87 seconds, approx. 5.19 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.3
# 		5.2. PSNR: 23.4
# 		5.3. PSNR: 27.6
# 		5.4. PSNR: 20.8
# 		5.5. PSNR: 23.6
# 		5.6. PSNR: 24.8
# 		5.7. PSNR: 28.6
# 		5.8. PSNR: 23.7
# 		5.9. PSNR: 28.6
# 		5.10. PSNR: 21.7
# 		5.11. PSNR: 23.8
# 		5.12. PSNR: 23.9
# 		5.13. PSNR: 28.0
# 		5.14. PSNR: 20.6
# 	Average PSNR: 24.242
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.687
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 256, 128, 16)
# 10 epochs completed in 1.0 minutes 25.16 seconds, approx. 8.52 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.1
# 		5.2. PSNR: 22.8
# 		5.3. PSNR: 25.4
# 		5.4. PSNR: 20.1
# 		5.5. PSNR: 23.6
# 		5.6. PSNR: 24.5
# 		5.7. PSNR: 26.9
# 		5.8. PSNR: 23.3
# 		5.9. PSNR: 27.8
# 		5.10. PSNR: 22.0
# 		5.11. PSNR: 23.0
# 		5.12. PSNR: 24.3
# 		5.13. PSNR: 26.6
# 		5.14. PSNR: 20.1
# 	Average PSNR: 23.606
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.684
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 256, 256, 1)
# 10 epochs completed in 0.0 minutes 29.43 seconds, approx. 2.94 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 20.4
# 		5.2. PSNR: 23.3
# 		5.3. PSNR: 27.7
# 		5.4. PSNR: 20.6
# 		5.5. PSNR: 23.8
# 		5.6. PSNR: 24.8
# 		5.7. PSNR: 28.5
# 		5.8. PSNR: 23.6
# 		5.9. PSNR: 29.0
# 		5.10. PSNR: 21.8
# 		5.11. PSNR: 23.9
# 		5.12. PSNR: 24.3
# 		5.13. PSNR: 28.0
# 		5.14. PSNR: 20.6
# 	Average PSNR: 24.305
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 2
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.4
# 		5.2. SSIM: 0.7
# 		5.3. SSIM: 0.7
# 		5.4. SSIM: 0.8
# 		5.5. SSIM: 0.7
# 		5.6. SSIM: 0.5
# 		5.7. SSIM: 0.9
# 		5.8. SSIM: 0.6
# 		5.9. SSIM: 0.7
# 		5.10. SSIM: 0.7
# 		5.11. SSIM: 0.7
# 		5.12. SSIM: 0.9
# 		5.13. SSIM: 0.7
# 		5.14. SSIM: 0.6
# 	Average SSIM: 0.690
#
# 	6. Plotting SSIM results:
#
# Model Architecture: (9, 5, 256, 256, 4)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-f270fc6ae245> in <module>
#      14         nlin_layers=arch[4],
#      15         activation='relu', optimizer='adam', loss='mse', metrics=['accuracy'], padding='valid', batch_norm=False)
# ---> 16     srcnn_m.fit(xdata=xdata, ydata=ydata, epochs=epochs, batch_size=batch_size, validation_split=0.1, verbose=0)
#      17     srcnn_m.plot_training(figsize=(16, 8), plot_vars=['loss', 'val_loss'])
#      18
#
# /tf/GitProjects/srcnn-tf2/srcnn_tf2/model/srcnn_model.py in fit(self, xdata, ydata, epochs, batch_size, validation_split, verbose)
#     134                                      batch_size=batch_size,
#     135                                      validation_split=validation_split,
# --> 136                                      verbose=verbose)
#     137         exec_time = time() - start_time
#     138         print(f"{epochs} epochs completed in {exec_time//60} minutes {exec_time%60:.2f} seconds, approx. {exec_time/epochs:.2f} seconds per epoch.")
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Train model
# Specify number of epochs and batch size. Use a small split for running validation, and plot the loss and validation loss.

# %%
print(f"| Scaling factor | Image Set | $f_1 / f_3 / n_1 / n_2 / n_nonlin$ | Bicubic - PSNR (mean) | SRCNN - PSNR (mean) | PSNR Mean Improvement | Bicubic - SSIM (mean) | SRCNN - SSIM (mean) | SSIM Mean Improvement |")
print(f"| :------------- | :-------: | :------------------------------------: | :-------------------: | :-----------------: | :-------------------: | :-------------------: | :-----------------: | :-------------------: |")
for p in result_strings:
    print(p)
# Out:
# | Scaling factor | Image Set | $f_1 / f_3 / n_1 / n_2 / n_nonlin$ | Bicubic - PSNR (mean) | SRCNN - PSNR (mean) | PSNR Mean Improvement | Bicubic - SSIM (mean) | SRCNN - SSIM (mean) | SSIM Mean Improvement |
# | :------------- | :-------: | :------------------------------------: | :-------------------: | :-----------------: | :-------------------: | :-------------------: | :-----------------: | :-------------------: |
# | $2\times$ | Set14 | 9 / 5 / 64 / 32 / 1 | $23.54$ dB | $24.35$ dB | $+0.81$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 64 / 32 / 4 | $23.54$ dB | $24.27$ dB | $+0.73$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 64 / 32 / 8 | $23.54$ dB | $24.21$ dB | $+0.67$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 64 / 32 / 16 | $23.54$ dB | $24.16$ dB | $+0.63$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 64 / 64 / 1 | $23.54$ dB | $23.74$ dB | $+0.20$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 64 / 64 / 4 | $23.54$ dB | $24.10$ dB | $+0.56$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 64 / 64 / 8 | $23.54$ dB | $24.11$ dB | $+0.57$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 64 / 64 / 16 | $23.54$ dB | $24.12$ dB | $+0.58$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 32 / 1 | $23.54$ dB | $24.04$ dB | $+0.50$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 32 / 4 | $23.54$ dB | $24.25$ dB | $+0.71$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 32 / 8 | $23.54$ dB | $23.78$ dB | $+0.24$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 32 / 16 | $23.54$ dB | $24.23$ dB | $+0.69$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 64 / 1 | $23.54$ dB | $24.26$ dB | $+0.72$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 64 / 4 | $23.54$ dB | $24.23$ dB | $+0.69$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 64 / 8 | $23.54$ dB | $23.81$ dB | $+0.27$ dB | $0.65$ | $0.68$ | $+0.03$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 64 / 16 | $23.54$ dB | $24.12$ dB | $+0.58$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 128 / 1 | $23.54$ dB | $24.35$ dB | $+0.81$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 128 / 4 | $23.54$ dB | $24.34$ dB | $+0.80$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 128 / 8 | $23.54$ dB | $23.37$ dB | $+-0.16$ dB | $0.65$ | $0.66$ | $+0.01$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 128 / 16 | $23.54$ dB | $24.04$ dB | $+0.50$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 32 / 1 | $23.54$ dB | $24.29$ dB | $+0.75$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 32 / 4 | $23.54$ dB | $23.81$ dB | $+0.27$ dB | $0.65$ | $0.68$ | $+0.03$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 32 / 8 | $23.54$ dB | $24.20$ dB | $+0.66$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 32 / 16 | $23.54$ dB | $24.21$ dB | $+0.67$ dB | $0.65$ | $0.68$ | $+0.03$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 64 / 1 | $23.54$ dB | $24.30$ dB | $+0.76$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 64 / 4 | $23.54$ dB | $24.09$ dB | $+0.55$ dB | $0.65$ | $0.68$ | $+0.03$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 64 / 8 | $23.54$ dB | $24.23$ dB | $+0.69$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 64 / 16 | $23.54$ dB | $24.18$ dB | $+0.65$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 128 / 1 | $23.54$ dB | $24.38$ dB | $+0.84$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 128 / 4 | $23.54$ dB | $24.17$ dB | $+0.64$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 128 / 8 | $23.54$ dB | $24.24$ dB | $+0.70$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 128 / 16 | $23.54$ dB | $23.61$ dB | $+0.07$ dB | $0.65$ | $0.68$ | $+0.03$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 256 / 1 | $23.54$ dB | $24.31$ dB | $+0.77$ dB | $0.65$ | $0.69$ | $+0.04$ |

# %% [markdown]
# | Scaling factor | Image Set | $f_1 / f_3 / n_1 / n_2 / n_nonlin$ | Bicubic - PSNR (mean) | SRCNN - PSNR (mean) | PSNR Mean Improvement | Bicubic - SSIM (mean) | SRCNN - SSIM (mean) | SSIM Mean Improvement |
# | :------------- | :-------: | :------------------------------------: | :-------------------: | :-----------------: | :-------------------: | :-------------------: | :-----------------: | :-------------------: |
# | $2\times$ | Set14 | 9 / 5 / 64 / 32 / 1 | $23.54$ dB | $24.35$ dB | $+0.81$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 64 / 32 / 4 | $23.54$ dB | $24.27$ dB | $+0.73$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 64 / 32 / 8 | $23.54$ dB | $24.21$ dB | $+0.67$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 64 / 32 / 16 | $23.54$ dB | $24.16$ dB | $+0.63$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 64 / 64 / 1 | $23.54$ dB | $23.74$ dB | $+0.20$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 64 / 64 / 4 | $23.54$ dB | $24.10$ dB | $+0.56$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 64 / 64 / 8 | $23.54$ dB | $24.11$ dB | $+0.57$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 64 / 64 / 16 | $23.54$ dB | $24.12$ dB | $+0.58$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 32 / 1 | $23.54$ dB | $24.04$ dB | $+0.50$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 32 / 4 | $23.54$ dB | $24.25$ dB | $+0.71$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 32 / 8 | $23.54$ dB | $23.78$ dB | $+0.24$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 32 / 16 | $23.54$ dB | $24.23$ dB | $+0.69$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 64 / 1 | $23.54$ dB | $24.26$ dB | $+0.72$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 64 / 4 | $23.54$ dB | $24.23$ dB | $+0.69$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 64 / 8 | $23.54$ dB | $23.81$ dB | $+0.27$ dB | $0.65$ | $0.68$ | $+0.03$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 64 / 16 | $23.54$ dB | $24.12$ dB | $+0.58$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 128 / 1 | $23.54$ dB | $24.35$ dB | $+0.81$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 128 / 4 | $23.54$ dB | $24.34$ dB | $+0.80$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 128 / 8 | $23.54$ dB | $23.37$ dB | $+-0.16$ dB | $0.65$ | $0.66$ | $+0.01$ |
# | $2\times$ | Set14 | 9 / 5 / 128 / 128 / 16 | $23.54$ dB | $24.04$ dB | $+0.50$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 32 / 1 | $23.54$ dB | $24.29$ dB | $+0.75$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 32 / 4 | $23.54$ dB | $23.81$ dB | $+0.27$ dB | $0.65$ | $0.68$ | $+0.03$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 32 / 8 | $23.54$ dB | $24.20$ dB | $+0.66$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 32 / 16 | $23.54$ dB | $24.21$ dB | $+0.67$ dB | $0.65$ | $0.68$ | $+0.03$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 64 / 1 | $23.54$ dB | $24.30$ dB | $+0.76$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 64 / 4 | $23.54$ dB | $24.09$ dB | $+0.55$ dB | $0.65$ | $0.68$ | $+0.03$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 64 / 8 | $23.54$ dB | $24.23$ dB | $+0.69$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 64 / 16 | $23.54$ dB | $24.18$ dB | $+0.65$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 128 / 1 | $23.54$ dB | $24.38$ dB | $+0.84$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 128 / 4 | $23.54$ dB | $24.17$ dB | $+0.64$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 128 / 8 | $23.54$ dB | $24.24$ dB | $+0.70$ dB | $0.65$ | $0.69$ | $+0.04$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 128 / 16 | $23.54$ dB | $23.61$ dB | $+0.07$ dB | $0.65$ | $0.68$ | $+0.03$ |
# | $2\times$ | Set14 | 9 / 5 / 256 / 256 / 1 | $23.54$ dB | $24.31$ dB | $+0.77$ dB | $0.65$ | $0.69$ | $+0.04$ |

# %% [markdown]
# ---
# ## CIFAR-10 Examples
# We use the CIFAR-10 dataset as a "real world" application where there is no target with which to compare. We upscale using both the trained SRCNN and bicubic interpolation, and compare visually (there is no metric in this case).
#
# Images are saved with tags so they can be included in the summary and compare across the three scaling factors.

# %%
from tensorflow.keras.datasets.cifar10 import load_data

# Data import and definition.
d_example_index = {'airplane': 30,
                   'automobile': 32,
                   'bird': 41,
                   'cat': 33,
                   'deer': 34,
                   'dog': 40,
                   'frog': 72,
                   'horse': 37,
                   'ship': 62,
                   'truck': 31}

(x_train, y_train), (x_test, y_test) = load_data()
del x_test
del y_test
del y_train

label_list, im_list = [], []
for di in d_example_index.keys():
    label_list.append(di)
    im_list.append(x_train[d_example_index[di]])

im_list = np.array(im_list) / 255.0

del x_train
# Save image string.
im_prefix = f'srcnn_baseline_{scaling_factor}x_'

# %%
im_pred = srcnn_model.predict(im_list)
im_scale = center_crop(
    images=scale_batch(im_list, (im_list.shape[2]*scaling_factor, im_list.shape[1]*scaling_factor)),
    remove_edge=(im_list.shape[1]*scaling_factor - im_pred.shape[1])//2)

print((im_list.shape[1]*scaling_factor - im_pred.shape[1])//2, im_list.shape[1]*scaling_factor, im_pred.shape[1])
# Out:
# 6 128 116

# %%
for label, image_raw, image_pred, image_scale in zip(label_list, list(im_list), list(im_pred), list(im_scale)):
    n_compare(
        im_list=[image_raw, image_scale, image_pred],
        label_list=[f'Original: {label.upper()} - [{image_raw.shape[1]} x {image_raw.shape[0]}]',
                    f'Bicubic Interpolation x{scaling_factor} - [{image_scale.shape[1]} x {image_scale.shape[0]}]',
                    f'SRCNN x{scaling_factor} - [{image_pred.shape[1]} x {image_pred.shape[0]}]'],
        figsize=(12,5))
    
    im = Image.fromarray(np.uint8(image_pred*255))
    im.save(f"results/{im_prefix}{label}.png")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

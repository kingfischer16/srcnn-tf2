# %% [markdown]
# # SRCNN - Effect of Different Activation Functions
# This notebook implements the super-resolution convolutional neural network, SRCNN, as described by [Dong *et al.*](https://link.springer.com/chapter/10.1007/978-3-319-10593-2_13).
#
# The notebook will cover tuning the basic SRCNN model for optimal performance by implementing what was learned from the previous notebooks. Performance will be assessed on two scaling factors described in the paper, $2\times$ and $4\times$. Results for each can be acquired by changing the scaling factor and re-running the notebook.
#
# ## Summary
# Results from this notebook are summarized in full at the end of the notebook. Using $32 \times 32$ training patches and a scaling factor of 2 or 4, image patch stride of 14, training batch size of 32 with 200 epochs, training took roughly 10 minutes on a GTX 1080 Ti (depending on architecture).
#
# | Scaling Factor | Image Set | Batch Norm | Dropout | Architecture | Activation Function | Mean PSNR | Mean SSIM |
# | :------------: | :-------: | :--------: | :-----: | :----------: | :-----------------: | :-------: | :-------: |
# | 2 | Set14 | False | None | ['9', '5', '64', '32', '1'] | relu | 24.42 | 0.6909 |
# | 2 | Set14 | False | None | ['9', '5', '64', '32', '4'] | relu | 24.33 | 0.6898 |
# | 2 | Set14 | False | None | ['9', '7', '64', '32', '1'] | relu | 24.31 | 0.6876 |
# | 2 | Set14 | False | None | ['9', '7', '128', '64', '1'] | relu | 24.32 | 0.6874 |
# | 4 | Set14 | False | None | ['9', '5', '64', '32', '1'] | relu | 20.83 | 0.5221 |
# | 6 | Set14 | False | None | ['9', '5', '64', '32', '1'] | relu | 19.32 | 0.4608 |
# | 6 | Set14 | True | 0.2 | ['13', '7', '128', '64', '4'] | relu | 18.78 | 0.4506 |

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# Imports.
import numpy as np
import pandas as pd
from PIL import Image

import site
site.addsitedir('../')
from srcnn_tf2.data.preprocessing import create_xy_patches, import_from_file, scale_batch, center_crop
from srcnn_tf2.data.plotting import n_compare
from srcnn_tf2.model.srcnn_model import SRCNN

# Data locations.
training_folder = '../../../sr_data/T91'
set5_eval_folder = '../../../sr_data/Set5'
set14_eval_folder = '../../../sr_data/Set14'

# %% [markdown]
# ---
# ## Import and preprocess training data
# High-resolution target images, $I_y$, are 32 x 32 pixel sub-images extracted from the original T91 image set. This is done by passing a 32 x 32 pixel window over the originals at a stride of 14 pixels. Target images are then given a Gaussian blur and downscaled by the scaling factor to produce the low-resolution input images, $I_x$. Each patch is then rotated by 90 degrees 3 times to produce 4 images per patch. Pre-upscaling for the model is performed as part of the model class.
#
# **Note** that applying the blur after the downscale produces better numerical and visual results on the images that are downscaled for validation (e.g. Set5 and Set14). However, applying the blur before downscaling, as in the paper, while returning seemingly worse numerical and visual results on the validation set, produces far more realistic images when tested on CIFAR-10.
#
# To avoid edge effects of convlution, padding in the model is set to `'valid'`, and $I_y$ images are center cropped to remove the edge, forcing the loss function to compare only the central $20 x 20$ section of the image.

# %%
# Data options.
# Note: 'scaling_factor' should evenly divide into 'y_image_size'.
y_image_size = (48, 48)  # Target image size, patches extracted from T91 inputs.
scaling_factor = 6
patch_stride = 14
blur_kernel = -1

# Data extraction.
xdata, ydata = create_xy_patches(training_folder,
                                 scaling_factor,
                                 patch_size=y_image_size,
                                 patch_stride=patch_stride,
                                 blur_kernel=blur_kernel,
                                 rotations=[0, 90, 180, 270], swap_channels=False)
print(f"Target data size (number of images x image shape x channels): {ydata.shape}")
print(f"Training data input size (number of images x image shape x channels): {xdata.shape}")
# Out:
# Target data size (number of images x image shape x channels): (78392, 48, 48, 3)
# Training data input size (number of images x image shape x channels): (78392, 8, 8, 3)

# %% [markdown]
# ## Define and train models
# ### Define model architectures
# Models are defined in a loop, using a range of parameters. Here we do a grid search across the whether or not we use batch normalization, as well as no dropout, and 0.2 and 0.5 fraction dropout.

# %% [markdown]
# ### Train model architectures
# Specify number of epochs and batch size. Use a small split for running validation, and plot the loss and validation loss.

# %%
# Images for testing.
testing_images_14 = import_from_file(set14_eval_folder)

# CIFAR-10 images
from tensorflow.keras.datasets.cifar10 import load_data

# Data import and definition.
d_example_index = {'airplane': 30,
                   'automobile': 32,
                   'bird': 41,
                   'cat': 33,
                   'deer': 34,
                   'dog': 40,
                   'frog': 72,
                   'horse': 37,
                   'ship': 62,
                   'truck': 31}

(x_train, y_train), (x_test, y_test) = load_data()
del x_test
del y_test
del y_train

label_list, im_list = [], []
for di in d_example_index.keys():
    label_list.append(di)
    im_list.append(x_train[d_example_index[di]])

im_list = np.array(im_list) / 255.0
im_scale = center_crop(images=scale_batch(im_list, (im_list.shape[2]*scaling_factor, im_list.shape[1]*scaling_factor)),
                       remove_edge=6)

del x_train
# Save image string.
im_prefix = f'srcnn_baseline_{scaling_factor}x_'

d_pred_images = {
    'Original': im_list,
    'Bicubic': im_scale
}

# %%
n_epochs = 500
b_size = 32

# Model architecture.
f1, f3, n1, n2, nlin = 13, 7, 128, 64, 4
act_func = 'relu'
b_norm = True
drop_frac = 0.2

model = SRCNN(num_channels=3, f1=f1, f3=f3, n1=n1, n2=n2, nlin_layers=nlin,
              activation=act_func, optimizer='adam', loss='mse', metrics=['accuracy'], padding='valid',
              batch_norm=b_norm, dropout=drop_frac)
print(f"\nModel Architecture: {' - '.join([str(a) for a in [f1, f3, n1, n2, nlin]])} | Batch Norm: {str(b_norm)} | Dropout: {str(drop_frac)} | Activation: {act_func.upper()}")
model.fit(xdata=xdata, ydata=ydata, epochs=n_epochs, batch_size=b_size, validation_split=0.1, verbose=1)
model.plot_training(figsize=(25, 5), plot_vars=['loss', 'val_loss'])
psnr_14, psnr_bicubic_14 = model.benchmark(testing_images_14, metric='psnr', return_metrics=True)
ssim_14, ssim_bicubic_14 = model.benchmark(testing_images_14, metric='ssim', return_metrics=True)
im_pred = model.predict(im_list)
d_pred_images['Opt Model'] = im_pred
print("| Scaling Factor | Image Set | Batch Norm. | Dropout | Architecture | Activation Function | Mean PSNR | Mean SSIM |")
print("| :------------: | :-------: | :-------------------: | :----------: | :-----------------: | :-------: | :-------: |")
print(f"| {scaling_factor} | Set14 | {str(b_norm)} | {str(drop_frac)} | {[str(a) for a in [f1, f3, n1, n2, nlin]]} | {act_func} | {np.mean(psnr_14):.2f} | {np.mean(ssim_14):.4f} |")
# Out:
# Model Architecture: 13 - 7 - 128 - 64 - 4 | Batch Norm: True | Dropout: 0.2 | Activation: RELU
# Epoch 1/500
# 2205/2205 [==============================] - ETA: 0s - loss: 0.0771 - accuracy: 0.6758WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0011s vs `on_test_batch_end` time: 0.0022s). Check your callbacks.
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0771 - accuracy: 0.6758 - val_loss: 0.0209 - val_accuracy: 0.7964
# Epoch 2/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0618 - accuracy: 0.7159 - val_loss: 0.0109 - val_accuracy: 0.9249
# Epoch 3/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0618 - accuracy: 0.7178 - val_loss: 0.0199 - val_accuracy: 0.8974
# Epoch 4/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0619 - accuracy: 0.7206 - val_loss: 0.0229 - val_accuracy: 0.8424
# Epoch 5/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0614 - accuracy: 0.7195 - val_loss: 0.0264 - val_accuracy: 0.9269
# Epoch 6/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0619 - accuracy: 0.7171 - val_loss: 0.0189 - val_accuracy: 0.9378
# Epoch 7/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0607 - accuracy: 0.7237 - val_loss: 0.0162 - val_accuracy: 0.9265
# Epoch 8/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0605 - accuracy: 0.7245 - val_loss: 0.0233 - val_accuracy: 0.9056
# Epoch 9/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0603 - accuracy: 0.7270 - val_loss: 0.0183 - val_accuracy: 0.9041
# Epoch 10/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0602 - accuracy: 0.7290 - val_loss: 0.0214 - val_accuracy: 0.9145
# Epoch 11/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0602 - accuracy: 0.7296 - val_loss: 0.0181 - val_accuracy: 0.9068
# Epoch 12/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0600 - accuracy: 0.7317 - val_loss: 0.0170 - val_accuracy: 0.9185
# Epoch 13/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0600 - accuracy: 0.7322 - val_loss: 0.0135 - val_accuracy: 0.9122
# Epoch 14/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0599 - accuracy: 0.7343 - val_loss: 0.0119 - val_accuracy: 0.9229
# Epoch 15/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0599 - accuracy: 0.7354 - val_loss: 0.0162 - val_accuracy: 0.9276
# Epoch 16/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0598 - accuracy: 0.7380 - val_loss: 0.0265 - val_accuracy: 0.8818
# Epoch 17/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0607 - accuracy: 0.7332 - val_loss: 0.0184 - val_accuracy: 0.9090
# Epoch 18/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0599 - accuracy: 0.7380 - val_loss: 0.0179 - val_accuracy: 0.8891
# Epoch 19/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0599 - accuracy: 0.7359 - val_loss: 0.0176 - val_accuracy: 0.9029
# Epoch 20/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0598 - accuracy: 0.7378 - val_loss: 0.0165 - val_accuracy: 0.9021
# Epoch 21/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0596 - accuracy: 0.7412 - val_loss: 0.0147 - val_accuracy: 0.9294
# Epoch 22/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0597 - accuracy: 0.7396 - val_loss: 0.0161 - val_accuracy: 0.9041
# Epoch 23/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0596 - accuracy: 0.7426 - val_loss: 0.0193 - val_accuracy: 0.9268
# Epoch 24/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0598 - accuracy: 0.7405 - val_loss: 0.0341 - val_accuracy: 0.4417
# Epoch 25/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0601 - accuracy: 0.7338 - val_loss: 0.0167 - val_accuracy: 0.9358
# Epoch 26/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0597 - accuracy: 0.7402 - val_loss: 0.0120 - val_accuracy: 0.9272
# Epoch 27/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0596 - accuracy: 0.7411 - val_loss: 0.0103 - val_accuracy: 0.8460
# Epoch 28/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0596 - accuracy: 0.7432 - val_loss: 0.0234 - val_accuracy: 0.8673
# Epoch 29/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0595 - accuracy: 0.7431 - val_loss: 0.0175 - val_accuracy: 0.8545
# Epoch 30/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0595 - accuracy: 0.7434 - val_loss: 0.0113 - val_accuracy: 0.9377
# Epoch 31/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0595 - accuracy: 0.7441 - val_loss: 0.0246 - val_accuracy: 0.9326
# Epoch 32/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.
500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7497 - val_loss: 0.0157 - val_accuracy: 0.9369
# Epoch 95/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7496 - val_loss: 0.0141 - val_accuracy: 0.9242
# Epoch 96/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7503 - val_loss: 0.0176 - val_accuracy: 0.9400
# Epoch 97/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7508 - val_loss: 0.0174 - val_accuracy: 0.9335
# Epoch 98/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7511 - val_loss: 0.0175 - val_accuracy: 0.9396
# Epoch 99/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7512 - val_loss: 0.0128 - val_accuracy: 0.9155
# Epoch 100/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7518 - val_loss: 0.0193 - val_accuracy: 0.9474
# Epoch 101/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7515 - val_loss: 0.0178 - val_accuracy: 0.9393
# Epoch 102/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7504 - val_loss: 0.0144 - val_accuracy: 0.9328
# Epoch 103/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0595 - accuracy: 0.7439 - val_loss: 0.0187 - val_accuracy: 0.9423
# Epoch 104/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0592 - accuracy: 0.7499 - val_loss: 0.0142 - val_accuracy: 0.9386
# Epoch 105/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7503 - val_loss: 0.0177 - val_accuracy: 0.9055
# Epoch 106/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7511 - val_loss: 0.0166 - val_accuracy: 0.9398
# Epoch 107/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7505 - val_loss: 0.0150 - val_accuracy: 0.9374
# Epoch 108/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7518 - val_loss: 0.0118 - val_accuracy: 0.9143
# Epoch 109/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7509 - val_loss: 0.0125 - val_accuracy: 0.9080
# Epoch 110/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7509 - val_loss: 0.0166 - val_accuracy: 0.9271
# Epoch 111/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7508 - val_loss: 0.0183 - val_accuracy: 0.9427
# Epoch 112/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0599 - accuracy: 0.7414 - val_loss: 0.0166 - val_accuracy: 0.9374
# Epoch 113/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7497 - val_loss: 0.0169 - val_accuracy: 0.9423
# Epoch 114/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7494 - val_loss: 0.0162 - val_accuracy: 0.9455
# Epoch 115/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7520 - val_loss: 0.0127 - val_accuracy: 0.9444
# Epoch 116/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7507 - val_loss: 0.0108 - val_accuracy: 0.9409
# Epoch 117/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7512 - val_loss: 0.0176 - val_accuracy: 0.9271
# Epoch 118/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7510 - val_loss: 0.0166 - val_accuracy: 0.9269
# Epoch 119/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7512 - val_loss: 0.0130 - val_accuracy: 0.8883
# Epoch 120/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0594 - accuracy: 0.7460 - val_loss: 0.0142 - val_accuracy: 0.9424
# Epoch 121/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7473 - val_loss: 0.0186 - val_accuracy: 0.9327
# Epoch 122/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7504 - val_loss: 0.0168 - val_accuracy: 0.9336
# Epoch 123/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7512 - val_loss: 0.0113 - val_accuracy: 0.9401
# Epoch 124/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7516 - val_loss: 0.0139 - val_accuracy: 0.9386
# Epoch 125/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7514 - val_loss: 0.0158 - val_accuracy: 0.9394
# Epoch 126/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7512 - val_loss: 0.0133 - val_accuracy: 0.9342
# Epoch 127/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7513 - val_loss: 0.0167 - val_accuracy: 0.9377
# Epoch 128/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7504 - val_loss: 0.0166 - val_accuracy: 0.9344
# Epoch 129/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7517 - val_loss: 0.0152 - val_accuracy: 0.9417
# Epoch 130/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7519 - val_loss: 0.0143 - val_accuracy: 0.9348
# Epoch 131/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0594 - accuracy: 0.7473 - val_loss: 0.0182 - val_accuracy: 0.9357
# Epoch 132/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7501 - val_loss: 0.0206 - val_accuracy: 0.9416
# Epoch 133/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7506 - val_loss: 0.0166 - val_accuracy: 0.9466
# Epoch 134/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.
500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7523 - val_loss: 0.0143 - val_accuracy: 0.9460
# Epoch 167/500
# 2205/2205 [==============================] - 30s 13ms/step - loss: 0.0589 - accuracy: 0.7525 - val_loss: 0.0175 - val_accuracy: 0.9301
# Epoch 168/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0590 - accuracy: 0.7521 - val_loss: 0.0155 - val_accuracy: 0.9215
# Epoch 169/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7526 - val_loss: 0.0163 - val_accuracy: 0.9446
# Epoch 170/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0590 - accuracy: 0.7509 - val_loss: 0.0174 - val_accuracy: 0.9266
# Epoch 171/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7524 - val_loss: 0.0147 - val_accuracy: 0.9334
# Epoch 172/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0590 - accuracy: 0.7519 - val_loss: 0.0164 - val_accuracy: 0.9386
# Epoch 173/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7521 - val_loss: 0.0159 - val_accuracy: 0.9412
# Epoch 174/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7526 - val_loss: 0.0122 - val_accuracy: 0.9331
# Epoch 175/500
# 2205/2205 [==============================] - 30s 13ms/step - loss: 0.0589 - accuracy: 0.7528 - val_loss: 0.0148 - val_accuracy: 0.9185
# Epoch 176/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7526 - val_loss: 0.0183 - val_accuracy: 0.9356
# Epoch 177/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7525 - val_loss: 0.0153 - val_accuracy: 0.9396
# Epoch 178/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7526 - val_loss: 0.0188 - val_accuracy: 0.9432
# Epoch 179/500
# 2205/2205 [==============================] - 30s 13ms/step - loss: 0.0589 - accuracy: 0.7518 - val_loss: 0.0190 - val_accuracy: 0.9299
# Epoch 180/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0592 - accuracy: 0.7470 - val_loss: 0.0194 - val_accuracy: 0.9229
# Epoch 181/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7502 - val_loss: 0.0168 - val_accuracy: 0.9428
# Epoch 182/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7526 - val_loss: 0.0173 - val_accuracy: 0.9463
# Epoch 183/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7525 - val_loss: 0.0156 - val_accuracy: 0.9181
# Epoch 184/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7529 - val_loss: 0.0168 - val_accuracy: 0.9309
# Epoch 185/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7488 - val_loss: 0.0153 - val_accuracy: 0.9329
# Epoch 186/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7507 - val_loss: 0.0197 - val_accuracy: 0.9389
# Epoch 187/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7528 - val_loss: 0.0147 - val_accuracy: 0.9461
# Epoch 188/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7525 - val_loss: 0.0145 - val_accuracy: 0.9458
# Epoch 189/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7512 - val_loss: 0.0142 - val_accuracy: 0.9308
# Epoch 190/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7528 - val_loss: 0.0133 - val_accuracy: 0.9280
# Epoch 191/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7528 - val_loss: 0.0138 - val_accuracy: 0.8673
# Epoch 192/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0590 - accuracy: 0.7519 - val_loss: 0.0127 - val_accuracy: 0.9344
# Epoch 193/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7531 - val_loss: 0.0180 - val_accuracy: 0.9297
# Epoch 194/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7520 - val_loss: 0.0151 - val_accuracy: 0.9320
# Epoch 195/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7529 - val_loss: 0.0175 - val_accuracy: 0.9356
# Epoch 196/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7525 - val_loss: 0.0171 - val_accuracy: 0.9211
# Epoch 197/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7527 - val_loss: 0.0171 - val_accuracy: 0.9472
# Epoch 198/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7527 - val_loss: 0.0176 - val_accuracy: 0.9357
# Epoch 199/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7529 - val_loss: 0.0164 - val_accuracy: 0.9328
# Epoch 200/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7528 - val_loss: 0.0183 - val_accuracy: 0.9305
# Epoch 201/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7525 - val_loss: 0.0150 - val_accuracy: 0.9438
# Epoch 202/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7526 - val_loss: 0.0143 - val_accuracy: 0.9361
# Epoch 203/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7530 - val_loss: 0.0150 - val_accuracy: 0.9205
# Epoch 204/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7526 - val_loss: 0.0178 - val_accuracy: 0.9453
# Epoch 205/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7528 - val_loss: 0.0161 - val_accuracy: 0.9414
# Epoch 206/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7527 - val_loss: 0.0135 - val_accuracy: 0.9327
# Epoch 207/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7532 - val_loss: 0.0160 - val_accuracy: 0.9313
# Epoch 208/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7533 - val_loss: 0.0159 - val_accuracy: 0.9290
# Epoch 209/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7534 - val_loss: 0.0157 - val_accuracy: 0.9315
# Epoch 210/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7536 - val_loss: 0.0185 - val_accuracy: 0.9318
# Epoch 211/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7529 - val_loss: 0.0179 - val_accuracy: 0.9233
# Epoch 212/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7526 - val_loss: 0.0164 - val_accuracy: 0.9221
# Epoch 213/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7528 - val_loss: 0.0160 - val_accuracy: 0.9255
# Epoch 214/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7530 - val_loss: 0.0176 - val_accuracy: 0.9473
# Epoch 215/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7527 - val_loss: 0.0184 - val_accuracy: 0.9389
# Epoch 216/500
# 2205/2205 [==============================] - 30s 13ms/step - loss: 0.0589 - accuracy: 0.7532 - val_loss: 0.0174 - val_accuracy: 0.9272
# Epoch 217/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7528 - val_loss: 0.0151 - val_accuracy: 0.9428
# Epoch 218/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7531 - val_loss: 0.0144 - val_accuracy: 0.9218
# Epoch 219/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7529 - val_loss: 0.0128 - val_accuracy: 0.9241
# Epoch 220/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7534 - val_loss: 0.0185 - val_accuracy: 0.9440
# Epoch 221/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7527 - val_loss: 0.0196 - val_accuracy: 0.9323
# Epoch 222/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7532 - val_loss: 0.0148 - val_accuracy: 0.9322
# Epoch 223/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7533 - val_loss: 0.0147 - val_accuracy: 0.9468
# Epoch 224/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7535 - val_loss: 0.0179 - val_accuracy: 0.9371
# Epoch 225/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7532 - val_loss: 0.0201 - val_accuracy: 0.9274
# Epoch 226/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7528 - val_loss: 0.0168 - val_accuracy: 0.9178
# Epoch 227/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7531 - val_loss: 0.0132 - val_accuracy: 0.9464
# Epoch 228/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7523 - val_loss: 0.0164 - val_accuracy: 0.9262
# Epoch 229/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7527 - val_loss: 0.0194 - val_accuracy: 0.9059
# Epoch 230/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7528 - val_loss: 0.0193 - val_accuracy: 0.9256
# Epoch 231/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7527 - val_loss: 0.0194 - val_accuracy: 0.9378
# Epoch 232/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0595 - accuracy: 0.7421 - val_loss: 0.0176 - val_accuracy: 0.9376
# Epoch 233/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0592 - accuracy: 0.7452 - val_loss: 0.0158 - val_accuracy: 0.9427
# Epoch 234/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0591 - accuracy: 0.7484 - val_loss: 0.0151 - val_accuracy: 0.9422
# Epoch 235/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0590 - accuracy: 0.7505 - val_loss: 0.0175 - val_accuracy: 0.9425
# Epoch 236/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7526 - val_loss: 0.0148 - val_accuracy: 0.9451
# Epoch 237/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7525 - val_loss: 0.0177 - val_accuracy: 0.8934
# Epoch 238/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7522 - val_loss: 0.0144 - val_accuracy: 0.9461
# Epoch 239/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7525 - val_loss: 0.0192 - val_accuracy: 0.9161
# Epoch 240/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0590 - accuracy: 0.7497 - val_loss: 0.0137 - val_accuracy: 0.9177
# Epoch 241/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7520 - val_loss: 0.0149 - val_accuracy: 0.9278
# Epoch 242/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7526 - val_loss: 0.0172 - val_accuracy: 0.9216
# Epoch 243/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7527 - val_loss: 0.0160 - val_accuracy: 0.9373
# Epoch 244/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7523 - val_loss: 0.0154 - val_accuracy: 0.9314
# Epoch 245/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7511 - val_loss: 0.0195 - val_accuracy: 0.9231
# Epoch 246/500
# 2205/2205 [==============================] - 30s 13ms/step - loss: 0.0589 - accuracy: 0.7520 - val_loss: 0.0139 - val_accuracy: 0.9284
# Epoch 247/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7528 - val_loss: 0.0151 - val_accuracy: 0.9292
# Epoch 248/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7526 - val_loss: 0.0207 - val_accuracy: 0.9451
# Epoch 249/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7528 - val_loss: 0.0164 - val_accuracy: 0.9289
# Epoch 250/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7529 - val_loss: 0.0162 - val_accuracy: 0.9324
# Epoch 251/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7530 - val_loss: 0.0148 - val_accuracy: 0.9299
# Epoch 252/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0591 - accuracy: 0.7506 - val_loss: 0.0144 - val_accuracy: 0.9331
# Epoch 253/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0590 - accuracy: 0.7500 - val_loss: 0.0152 - val_accuracy: 0.9421
# Epoch 254/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7523 - val_loss: 0.0156 - val_accuracy: 0.9268
# Epoch 255/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7523 - val_loss: 0.0136 - val_accuracy: 0.9354
# Epoch 256/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7530 - val_loss: 0.0161 - val_accuracy: 0.9353
# Epoch 257/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7534 - val_loss: 0.0156 - val_accuracy: 0.9454
# Epoch 258/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7528 - val_loss: 0.0154 - val_accuracy: 0.9314
# Epoch 259/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7532 - val_loss: 0.0176 - val_accuracy: 0.9298
# Epoch 260/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7531 - val_loss: 0.0152 - val_accuracy: 0.9308
# Epoch 261/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7530 - val_loss: 0.0144 - val_accuracy: 0.9327
# Epoch 262/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7539 - val_loss: 0.0184 - val_accuracy: 0.9244
# Epoch 263/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7531 - val_loss: 0.0175 - val_accuracy: 0.9409
# Epoch 264/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7511 - val_loss: 0.0165 - val_accuracy: 0.9295
# Epoch 265/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7513 - val_loss: 0.0162 - val_accuracy: 0.9401
# Epoch 266/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7523 - val_loss: 0.0134 - val_accuracy: 0.9252
# Epoch 267/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7520 - val_loss: 0.0172 - val_accuracy: 0.9165
# Epoch 268/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0590 - accuracy: 0.7509 - val_loss: 0.0166 - val_accuracy: 0.9322
# Epoch 269/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7518 - val_loss: 0.0198 - val_accuracy: 0.9407
# Epoch 270/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7530 - val_loss: 0.0171 - val_accuracy: 0.9301
# Epoch 271/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0594 - accuracy: 0.7487 - val_loss: 0.0196 - val_accuracy: 0.9352
# Epoch 272/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0590 - accuracy: 0.7504 - val_loss: 0.0159 - val_accuracy: 0.9211
# Epoch 273/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7530 - val_loss: 0.0183 - val_accuracy: 0.9266
# Epoch 274/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7529 - val_loss: 0.0163 - val_accuracy: 0.9369
# Epoch 275/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7531 - val_loss: 0.0168 - val_accuracy: 0.8338
# Epoch 276/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7528 - val_loss: 0.0131 - val_accuracy: 0.9280
# Epoch 277/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7528 - val_loss: 0.0168 - val_accuracy: 0.9274
# Epoch 278/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7529 - val_loss: 0.0143 - val_accuracy: 0.9172
# Epoch 279/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7531 - val_loss: 0.0184 - val_accuracy: 0.9333
# Epoch 280/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7528 - val_loss: 0.0159 - val_accuracy: 0.9283
# Epoch 281/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7534 - val_loss: 0.0154 - val_accuracy: 0.9363
# Epoch 282/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7531 - val_loss: 0.0150 - val_accuracy: 0.8975
# Epoch 283/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7536 - val_loss: 0.0156 - val_accuracy: 0.9290
# Epoch 284/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7526 - val_loss: 0.0177 - val_accuracy: 0.9444
# Epoch 285/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7528 - val_loss: 0.0143 - val_accuracy: 0.9090
# Epoch 286/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7532 - val_loss: 0.0146 - val_accuracy: 0.9191
# Epoch 287/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7533 - val_loss: 0.0182 - val_accuracy: 0.9334
# Epoch 288/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7533 - val_loss: 0.0126 - val_accuracy: 0.9328
# Epoch 289/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7536 - val_loss: 0.0200 - val_accuracy: 0.9248
# Epoch 290/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7522 - val_loss: 0.0213 - val_accuracy: 0.9253
# Epoch 291/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7532 - val_loss: 0.0160 - val_accuracy: 0.9096
# Epoch 292/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7538 - val_loss: 0.0157 - val_accuracy: 0.9394
# Epoch 293/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7529 - val_loss: 0.0169 - val_accuracy: 0.9343
# Epoch 294/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7527 - val_loss: 0.0148 - val_accuracy: 0.9322
# Epoch 295/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7527 - val_loss: 0.0169 - val_accuracy: 0.9130
# Epoch 296/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7534 - val_loss: 0.0174 - val_accuracy: 0.9257
# Epoch 297/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7531 - val_loss: 0.0151 - val_accuracy: 0.9313
# Epoch 298/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7536 - val_loss: 0.0167 - val_accuracy: 0.9387
# Epoch 299/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7529 - val_loss: 0.0181 - val_accuracy: 0.9405
# Epoch 300/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7539 - val_loss: 0.0171 - val_accuracy: 0.9296
# Epoch 301/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7531 - val_loss: 0.0146 - val_accuracy: 0.9209
# Epoch 302/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7534 - val_loss: 0.0136 - val_accuracy: 0.9178
# Epoch 303/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7536 - val_loss: 0.0175 - val_accuracy: 0.9339
# Epoch 304/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7541 - val_loss: 0.0200 - val_accuracy: 0.8555
# Epoch 305/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7537 - val_loss: 0.0145 - val_accuracy: 0.8368
# Epoch 306/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7542 - val_loss: 0.0190 - val_accuracy: 0.9380
# Epoch 307/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7539 - val_loss: 0.0146 - val_accuracy: 0.9055
# Epoch 308/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7539 - val_loss: 0.0156 - val_accuracy: 0.9344
# Epoch 309/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0591 - accuracy: 0.7492 - val_loss: 0.0159 - val_accuracy: 0.9322
# Epoch 310/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7502 - val_loss: 0.0154 - val_accuracy: 0.9357
# Epoch 311/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7533 - val_loss: 0.0190 - val_accuracy: 0.9163
# Epoch 312/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7530 - val_loss: 0.0163 - val_accuracy: 0.9280
# Epoch 313/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7538 - val_loss: 0.0139 - val_accuracy: 0.9396
# Epoch 314/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7535 - val_loss: 0.0174 - val_accuracy: 0.9114
# Epoch 315/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7536 - val_loss: 0.0151 - val_accuracy: 0.9281
# Epoch 316/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7534 - val_loss: 0.0172 - val_accuracy: 0.9237
# Epoch 317/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7532 - val_loss: 0.0200 - val_accuracy: 0.8139
# Epoch 318/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7530 - val_loss: 0.0186 - val_accuracy: 0.9345
# Epoch 319/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7538 - val_loss: 0.0161 - val_accuracy: 0.9374
# Epoch 320/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7537 - val_loss: 0.0164 - val_accuracy: 0.9076
# Epoch 321/500
# ...
# Epoch 405/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7541 - val_loss: 0.0175 - val_accuracy: 0.8514
# Epoch 406/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7536 - val_loss: 0.0150 - val_accuracy: 0.8066
# Epoch 407/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0590 - accuracy: 0.7472 - val_loss: 0.0160 - val_accuracy: 0.9334
# Epoch 408/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7521 - val_loss: 0.0166 - val_accuracy: 0.9357
# Epoch 409/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7532 - val_loss: 0.0174 - val_accuracy: 0.9333
# Epoch 410/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7536 - val_loss: 0.0170 - val_accuracy: 0.9416
# Epoch 411/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7534 - val_loss: 0.0152 - val_accuracy: 0.9258
# Epoch 412/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7539 - val_loss: 0.0149 - val_accuracy: 0.9290
# Epoch 413/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7540 - val_loss: 0.0154 - val_accuracy: 0.9394
# Epoch 414/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7535 - val_loss: 0.0163 - val_accuracy: 0.9216
# Epoch 415/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7537 - val_loss: 0.0155 - val_accuracy: 0.9188
# Epoch 416/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7536 - val_loss: 0.0148 - val_accuracy: 0.9283
# Epoch 417/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7541 - val_loss: 0.0167 - val_accuracy: 0.9349
# Epoch 418/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7542 - val_loss: 0.0147 - val_accuracy: 0.9334
# Epoch 419/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7535 - val_loss: 0.0164 - val_accuracy: 0.9309
# Epoch 420/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7540 - val_loss: 0.0162 - val_accuracy: 0.9411
# Epoch 421/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7540 - val_loss: 0.0163 - val_accuracy: 0.9412
# Epoch 422/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7540 - val_loss: 0.0151 - val_accuracy: 0.9362
# Epoch 423/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7536 - val_loss: 0.0210 - val_accuracy: 0.9269
# Epoch 424/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7541 - val_loss: 0.0208 - val_accuracy: 0.9293
# Epoch 425/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7535 - val_loss: 0.0185 - val_accuracy: 0.9270
# Epoch 426/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7537 - val_loss: 0.0155 - val_accuracy: 0.9353
# Epoch 427/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7537 - val_loss: 0.0176 - val_accuracy: 0.9341
# Epoch 428/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7539 - val_loss: 0.0161 - val_accuracy: 0.9379
# Epoch 429/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7539 - val_loss: 0.0142 - val_accuracy: 0.9401
# Epoch 430/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7533 - val_loss: 0.0160 - val_accuracy: 0.9202
# Epoch 431/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7534 - val_loss: 0.0138 - val_accuracy: 0.9161
# Epoch 432/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7527 - val_loss: 0.0151 - val_accuracy: 0.9457
# Epoch 433/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7539 - val_loss: 0.0194 - val_accuracy: 0.9356
# Epoch 434/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7541 - val_loss: 0.0190 - val_accuracy: 0.9328
# Epoch 435/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7538 - val_loss: 0.0168 - val_accuracy: 0.9136
# Epoch 436/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7540 - val_loss: 0.0154 - val_accuracy: 0.9325
# Epoch 437/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7537 - val_loss: 0.0188 - val_accuracy: 0.9345
# Epoch 438/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7530 - val_loss: 0.0156 - val_accuracy: 0.9358
# Epoch 439/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7541 - val_loss: 0.0162 - val_accuracy: 0.9359
# Epoch 440/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0587 - accuracy: 0.7538 - val_loss: 0.0161 - val_accuracy: 0.9446
# Epoch 441/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7542 - val_loss: 0.0174 - val_accuracy: 0.9322
# Epoch 442/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7535 - val_loss: 0.0156 - val_accuracy: 0.9247
# Epoch 443/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7521 - val_loss: 0.0197 - val_accuracy: 0.9363
# Epoch 444/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7534 - val_loss: 0.0146 - val_accuracy: 0.9389
# Epoch 445/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7534 - val_loss: 0.0169 - val_accuracy: 0.9188
# Epoch 446/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7535 - val_loss: 0.0160 - val_accuracy: 0.9451
# Epoch 447/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7538 - val_loss: 0.0158 - val_accuracy: 0.9435
# Epoch 448/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7530 - val_loss: 0.0165 - val_accuracy: 0.9231
# Epoch 449/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7544 - val_loss: 0.0171 - val_accuracy: 0.9354
# Epoch 450/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7540 - val_loss: 0.0144 - val_accuracy: 0.9400
# Epoch 451/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7537 - val_loss: 0.0158 - val_accuracy: 0.9397
# Epoch 452/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0593 - accuracy: 0.7398 - val_loss: 0.0155 - val_accuracy: 0.9356
# Epoch 453/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0589 - accuracy: 0.7518 - val_loss: 0.0160 - val_accuracy: 0.9402
# Epoch 454/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7535 - val_loss: 0.0153 - val_accuracy: 0.9376
# Epoch 455/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7538 - val_loss: 0.0153 - val_accuracy: 0.9430
# Epoch 456/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7537 - val_loss: 0.0170 - val_accuracy: 0.9333
# Epoch 457/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7534 - val_loss: 0.0159 - val_accuracy: 0.9421
# Epoch 458/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7542 - val_loss: 0.0150 - val_accuracy: 0.9358
# Epoch 459/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7537 - val_loss: 0.0160 - val_accuracy: 0.9353
# Epoch 460/500
# 2205/2205 [==============================] - 29s 13ms/step - loss: 0.0588 - accuracy: 0.7541 - val_loss: 0.0160 - val_accuracy: 0.9409
# Epoch 461/500
# 2205/2205 [==============================] - 31s 14ms/step - loss: 0.0588 - accuracy: 0.7531 - val_loss: 0.0169 - val_accuracy: 0.9385
# Epoch 462/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0589 - accuracy: 0.7526 - val_loss: 0.0160 - val_accuracy: 0.9283
# Epoch 463/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7542 - val_loss: 0.0183 - val_accuracy: 0.9360
# Epoch 464/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7539 - val_loss: 0.0178 - val_accuracy: 0.9258
# Epoch 465/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7534 - val_loss: 0.0166 - val_accuracy: 0.9411
# Epoch 466/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7547 - val_loss: 0.0149 - val_accuracy: 0.9067
# Epoch 467/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7537 - val_loss: 0.0099 - val_accuracy: 0.9050
# Epoch 468/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7538 - val_loss: 0.0179 - val_accuracy: 0.9233
# Epoch 469/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7538 - val_loss: 0.0136 - val_accuracy: 0.9355
# Epoch 470/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7544 - val_loss: 0.0138 - val_accuracy: 0.9399
# Epoch 471/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7540 - val_loss: 0.0142 - val_accuracy: 0.9234
# Epoch 472/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7543 - val_loss: 0.0163 - val_accuracy: 0.9386
# Epoch 473/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7540 - val_loss: 0.0202 - val_accuracy: 0.9450
# Epoch 474/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7532 - val_loss: 0.0216 - val_accuracy: 0.9281
# Epoch 475/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7537 - val_loss: 0.0160 - val_accuracy: 0.9239
# Epoch 476/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7537 - val_loss: 0.0147 - val_accuracy: 0.9283
# Epoch 477/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7542 - val_loss: 0.0152 - val_accuracy: 0.9327
# Epoch 478/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7545 - val_loss: 0.0161 - val_accuracy: 0.9042
# Epoch 479/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7535 - val_loss: 0.0198 - val_accuracy: 0.9351
# Epoch 480/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7538 - val_loss: 0.0150 - val_accuracy: 0.9049
# Epoch 481/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7537 - val_loss: 0.0152 - val_accuracy: 0.9272
# Epoch 482/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0587 - accuracy: 0.7544 - val_loss: 0.0151 - val_accuracy: 0.9357
# Epoch 483/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7540 - val_loss: 0.0164 - val_accuracy: 0.9228
# Epoch 484/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7532 - val_loss: 0.0134 - val_accuracy: 0.9119
# Epoch 485/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7533 - val_loss: 0.0173 - val_accuracy: 0.9242
# Epoch 486/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7537 - val_loss: 0.0146 - val_accuracy: 0.9414
# Epoch 487/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7537 - val_loss: 0.0178 - val_accuracy: 0.9265
# Epoch 488/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7536 - val_loss: 0.0164 - val_accuracy: 0.9235
# Epoch 489/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7543 - val_loss: 0.0170 - val_accuracy: 0.9220
# Epoch 490/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7544 - val_loss: 0.0164 - val_accuracy: 0.9456
# Epoch 491/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0587 - accuracy: 0.7541 - val_loss: 0.0141 - val_accuracy: 0.9383
# Epoch 492/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7539 - val_loss: 0.0155 - val_accuracy: 0.9401
# Epoch 493/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7545 - val_loss: 0.0166 - val_accuracy: 0.9236
# Epoch 494/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7537 - val_loss: 0.0166 - val_accuracy: 0.9190
# Epoch 495/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7542 - val_loss: 0.0138 - val_accuracy: 0.9071
# Epoch 496/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7540 - val_loss: 0.0159 - val_accuracy: 0.9387
# Epoch 497/500
# 2205/2205 [==============================] - 28s 13ms/step - loss: 0.0588 - accuracy: 0.7543 - val_loss: 0.0159 - val_accuracy: 0.9308
# Epoch 498/500
# 2205/2205 [==============================] - 27s 12ms/step - loss: 0.0589 - accuracy: 0.7523 - val_loss: 0.0160 - val_accuracy: 0.9367
# Epoch 499/500
# 2205/2205 [==============================] - 28s 12ms/step - loss: 0.0588 - accuracy: 0.7522 - val_loss: 0.0174 - val_accuracy: 0.9356
# Epoch 500/500
# 2205/2205 [==============================] - 28s 12ms/step - loss: 0.0588 - accuracy: 0.7539 - val_loss: 0.0188 - val_accuracy: 0.9395
# 500 epochs completed in 239.0 minutes 53.52 seconds, approx. 28.79 seconds per epoch.
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 6
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: PSNR
#
# 	5. PSNR results:
# 		5.1. PSNR: 18.2
# 		5.2. PSNR: 13.4
# 		5.3. PSNR: 21.4
# 		5.4. PSNR: 15.7
# 		5.5. PSNR: 19.9
# 		5.6. PSNR: 17.0
# 		5.7. PSNR: 22.1
# 		5.8. PSNR: 19.3
# 		5.9. PSNR: 21.8
# 		5.10. PSNR: 18.0
# 		5.11. PSNR: 18.8
# 		5.12. PSNR: 18.4
# 		5.13. PSNR: 22.5
# 		5.14. PSNR: 16.5
# 	Average PSNR: 18.779
#
# 	6. Plotting PSNR results:
# -------------------------------------------------------------------
# Starting model benchmark...
#
# 	1. Scaling test images to divide evenly by model scaling factor: 6
#
# 	2. Downscaling and blurring test images for prediction input.
#
# 	3. Predicting images using model.
#
# 	4. Calculating metric: SSIM
#
# 	5. SSIM results:
# 		5.1. SSIM: 0.2
# 		5.2. SSIM: 0.3
# 		5.3. SSIM: 0.6
# 		5.4. SSIM: 0.6
# 		5.5. SSIM: 0.5
# 		5.6. SSIM: 0.3
# 		5.7. SSIM: 0.7
# 		5.8. SSIM: 0.3
# 		5.9. SSIM: 0.4
# 		5.10. SSIM: 0.4
# 		5.11. SSIM: 0.4
# 		5.12. SSIM: 0.7
# 		5.13. SSIM: 0.6
# 		5.14. SSIM: 0.3
# 	Average SSIM: 0.451
#
# 	6. Plotting SSIM results:
# | Scaling Factor | Image Set | Batch Norm. | Dropout | Architecture | Activation Function | Mean PSNR | Mean SSIM |
# | :------------: | :-------: | :-------------------: | :----------: | :-----------------: | :-------: | :-------: |
# | 6 | Set14 | True | 0.2 | ['13', '7', '128', '64', '4'] | relu | 18.78 | 0.4506 |

# %%
arch_labels = ['Original', 'Bicubic', 'Opt Model']

for i, label in enumerate(label_list):
    image_list = [d_pred_images[a][i] for a in arch_labels]
    n_compare(
    im_list=image_list,
    label_list=[str(a) for a in arch_labels],
    figsize=(20,5)
    )

# %%
for d, im in d_pred_images.items():
    print(f"{d} range [{im.min()} - {im.max()}]")
# Out:
# Original range [0.0 - 1.0]
# Bicubic range [0.0 - 1.0]
# Opt Model range [0.0 - 0.8071764707565308]

# %%
#model.model.save(f'../trained_models/20201107_basic_{scaling_factor}x_srcnn')
model.model.save(f'../trained_models/20201107_{f1}_{f3}_{n1}_{n2}_{nlin}_{scaling_factor}x_srcnn')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ../trained_models/20201107_13_7_128_64_4_6x_srcnn/assets

# %% [markdown]
# ---
# ## CIFAR-10 Examples
# We use the CIFAR-10 dataset as a "real world" application where there is no target with which to compare. We upscale using both the trained SRCNN and bicubic interpolation, and compare visually (there is no metric in this case).
#
# Images are saved with tags so they can be included in the summary and compare across the three scaling factors.

# %%
from tensorflow.keras.datasets.cifar10 import load_data

# Data import and definition.
d_example_index = {'airplane': 30,
                   'automobile': 32,
                   'bird': 41,
                   'cat': 33,
                   'deer': 34,
                   'dog': 40,
                   'frog': 72,
                   'horse': 37,
                   'ship': 62,
                   'truck': 31}

(x_train, y_train), (x_test, y_test) = load_data()
del x_test
del y_test
del y_train

label_list, im_list = [], []
for di in d_example_index.keys():
    label_list.append(di)
    im_list.append(x_train[d_example_index[di]])

im_list = np.array(im_list) / 255.0

del x_train
# Save image string.
im_prefix = f'srcnn_baseline_{scaling_factor}x_'

# %%
im_pred = srcnn_model.predict(im_list)
im_scale = center_crop(
    images=scale_batch(im_list, (im_list.shape[2]*scaling_factor, im_list.shape[1]*scaling_factor)),
    remove_edge=(im_list.shape[1]*scaling_factor - im_pred.shape[1])//2)

print((im_list.shape[1]*scaling_factor - im_pred.shape[1])//2, im_list.shape[1]*scaling_factor, im_pred.shape[1])
# Out:
# 6 64 52

# %%
for label, image_raw, image_pred, image_scale in zip(label_list, list(im_list), list(im_pred), list(im_scale)):
    n_compare(
        im_list=[image_raw, image_scale, image_pred],
        label_list=[f'Original: {label.upper()} - [{image_raw.shape[1]} x {image_raw.shape[0]}]',
                    f'Bicubic Interpolation x{scaling_factor} - [{image_scale.shape[1]} x {image_scale.shape[0]}]',
                    f'SRCNN x{scaling_factor} - [{image_pred.shape[1]} x {image_pred.shape[0]}]'],
        figsize=(12,5))
    
    im = Image.fromarray(np.uint8(image_pred*255))
    im.save(f"results/{im_prefix}{label}.png")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
